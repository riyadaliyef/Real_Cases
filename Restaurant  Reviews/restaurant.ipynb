# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (0.18.0.post0)Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: C:\Users\User\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip
# Requirement already satisfied: nltk>=3.8 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.8->textblob) (8.1.7)
# Requirement already satisfied: joblib in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.8->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.8->textblob) (2024.7.24)
# Requirement already satisfied: tqdm in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.8->textblob) (4.66.5)
# Requirement already satisfied: colorama in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from click->nltk>=3.8->textblob) (0.4.6)

# %%
from textblob import TextBlob 
import matplotlib.pyplot as plt

# %%
import pandas
df= pd.read_csv("Reviews.csv")
print(df.head())
reviews = df['Review']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import pandas
#       2 df= pd.read_csv("Reviews.csv")
#       3 print(df.head())
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\__init__.py:152
#     134 from pandas.core.reshape.api import (
#     135     concat,
#     136     lreshape,
#    (...)
#     148     qcut,
#     149 )
#     151 from pandas import api, arrays, errors, io, plotting, tseries
# --> 152 from pandas import testing
#     153 from pandas.util._print_versions import show_versions
#     155 from pandas.io.api import (
#     156     # excel
#     157     ExcelFile,
#    (...)
#     185     read_spss,
#     186 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\testing.py:6
#       1 """
#       2 Public testing utility functions.
#       3 """
# ----> 6 from pandas._testing import (
#       7     assert_extension_array_equal,
#       8     assert_frame_equal,
#       9     assert_index_equal,
#      10     assert_series_equal,
#      11 )
#      13 __all__ = [
#      14     "assert_extension_array_equal",
#      15     "assert_frame_equal",
#      16     "assert_series_equal",
#      17     "assert_index_equal",
#      18 ]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_testing\__init__.py:404
#     399     import pytest
#     401     return pytest.raises(expected_exception, match=None)
# --> 404 cython_table = pd.core.common._cython_table.items()
#     407 def get_cython_table_params(ndframe, func_names_and_expected):
#     408     """
#     409     Combine frame, functions from com._cython_table
#     410     keys and expected result.
#    (...)
#     422         List of three items (DataFrame, function, expected result)
#     423     """
#
# AttributeError: partially initialized module 'pandas' has no attribute 'core' (most likely due to a circular import)

# %%
def get_sentiment(review):
    analysis = TextBlob(review)
    if analysis.sentiment.polarity > 0:
        return 'Positive'
    elif analysis.sentiment.polarity == 0:
        return 'Neutral'
    else:
        return 'Negative'

# %%
df['Sentiment'] = reviews.apply(get_sentiment)
sentiment_counts = df['Sentiment'].value_counts()

# %%
plt.figure(figsize=(8, 5))
plt.bar(sentiment_counts.index, sentiment_counts.values, color=['green', 'red', 'blue'])
plt.title('Sentiment Analysis of Restaurant Reviews')
plt.xlabel('Sentiment')
plt.ylabel('number of reviews')
plt.show()
